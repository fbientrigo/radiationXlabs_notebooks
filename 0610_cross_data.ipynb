# %% [markdown]
# # Merge All Data Sources
#
# This notebook merges DMM (current), VerDAC (voltage) and Beam (particle count) datasets by:
#
# 1. Converting all timestamps to a common unit (picoseconds, ps)
# 2. Labeling event groups based on markers
# 3. Aligning and joining data using `pandas.merge_asof` with configurable tolerances
#
# The resulting unified DataFrame will be efficient for downstream analysis and visualization.
#
# **Tools used:**
# - pandas
# - numpy
# - unyt
# - matplotlib
# - seaborn

# %%
# here are all the paths and style of data path

# verdaq
# 0_raw\verdaq_data_2022_05_25-29_all.csv
